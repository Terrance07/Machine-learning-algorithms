# %% [markdown]
# <a href="https://colab.research.google.com/github/Terrance07/Linear_Regression/blob/main/Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = {
    'Hours_Studied': [1, 2, 3, 4, 5],
    'Exam_Score': [55, 65, 75, 85, 95]
        }
df = pd.DataFrame(data)

# %%
X = df[['Hours_Studied']]
y= df['Exam_Score']

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
predictions = model.predict([[3]])
print("prediction Output",predictions)
# Out:
# prediction Output [75.]
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.pie(df['Exam_Score'], labels=df['Hours_Studied'], autopct='%1.1f%%')
plt.title("Exam Score Distribution")
plt.show()

# %%
plt.scatter(df['Hours_Studied'], df['Exam_Score'])
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.title("Hours Studied vs Exam Score")
plt.show()

# %%
plt.boxplot(df['Exam_Score'])
plt.ylabel("Exam Score")
plt.title("Exam Score Distribution")
plt.show()
